# %%
import pandas as pd

#Reads the data
rawdata = pd.read_csv('./Demanda_2015.txt', sep=';', encoding='utf-8')

# %%
rawdata.head()
# Out:
#      date  time  consumption
# 0  1/1/15  0:00        25459
# 1  1/1/15  0:10        25591
# 2  1/1/15  0:20        25531
# 3  1/1/15  0:30        25453
# 4  1/1/15  0:40        25329

# %%
import matplotlib.pyplot as plt

#groups data per day (header is date;time;consumption where date is the dd/mm/yy and time is the hour)
unique_times = rawdata['time'].unique().tolist()

data_per_day = rawdata.groupby('date')

#print(data.head())
plt.figure(figsize=(14, 8))
for day, group in data_per_day:
    plt.plot(group['time'], group['consumption'], label=day)

plt.xticks(range(0, len(unique_times), 6), unique_times[::6], rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x21a63a52870>,
#   <matplotlib.axis.XTick at 0x21a6300e0c0>,
#   <matplotlib.axis.XTick at 0x21a63a51d60>,
#   <matplotlib.axis.XTick at 0x21a5ffb0650>,
#   <matplotlib.axis.XTick at 0x21a62f1cef0>,
#   <matplotlib.axis.XTick at 0x21a62f1d580>,
#   <matplotlib.axis.XTick at 0x21a62f1d820>,
#   <matplotlib.axis.XTick at 0x21a62f1f650>,
#   <matplotlib.axis.XTick at 0x21a62f1ebd0>,
#   <matplotlib.axis.XTick at 0x21a62f1c5c0>,
#   <matplotlib.axis.XTick at 0x21a6306c350>,
#   <matplotlib.axis.XTick at 0x21a6306cf50>,
#   <matplotlib.axis.XTick at 0x21a6306dc10>,
#   <matplotlib.axis.XTick at 0x21a62f1e240>,
#   <matplotlib.axis.XTick at 0x21a6306c5c0>,
#   <matplotlib.axis.XTick at 0x21a6306f290>,
#   <matplotlib.axis.XTick at 0x21a6306ffb0>,
#   <matplotlib.axis.XTick at 0x21a62f7d730>,
#   <matplotlib.axis.XTick at 0x21a62f7deb0>,
#   <matplotlib.axis.XTick at 0x21a5f4545f0>,
#   <matplotlib.axis.XTick at 0x21a62f7c890>,
#   <matplotlib.axis.XTick at 0x21a62f7dca0>,
#   <matplotlib.axis.XTick at 0x21a62f7d5b0>,
#   <matplotlib.axis.XTick at 0x21a62f7efc0>],
#  [Text(0, 0, '0:00'),
#   Text(6, 0, '1:00'),
#   Text(12, 0, '2:00'),
#   Text(18, 0, '3:00'),
#   Text(24, 0, '4:00'),
#   Text(30, 0, '5:00'),
#   Text(36, 0, '6:00'),
#   Text(42, 0, '7:00'),
#   Text(48, 0, '8:00'),
#   Text(54, 0, '9:00'),
#   Text(60, 0, '10:00'),
#   Text(66, 0, '11:00'),
#   Text(72, 0, '12:00'),
#   Text(78, 0, '13:00'),
#   Text(84, 0, '14:00'),
#   Text(90, 0, '15:00'),
#   Text(96, 0, '16:00'),
#   Text(102, 0, '17:00'),
#   Text(108, 0, '18:00'),
#   Text(114, 0, '19:00'),
#   Text(120, 0, '20:00'),
#   Text(126, 0, '21:00'),
#   Text(132, 0, '22:00'),
#   Text(138, 0, '23:00')])
